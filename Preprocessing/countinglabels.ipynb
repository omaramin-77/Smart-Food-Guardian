# %%
import pandas as pd

df = pd.read_csv("snacks_openfoodfacts.csv") 
df["nutriscore_letter"].value_counts(dropna=True)
# Out:
# nutriscore_letter
# A    1599
# E    1159
# D    1115
# B    1064
# C    1052
# Name: count, dtype: int64
